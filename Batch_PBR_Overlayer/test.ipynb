# %%
from PIL import Image
# %matplotlib inline
import matplotlib.pyplot as plt 
import numpy as np 
import png

# %%
img_over = np.asarray(Image.open('NAPPs/result/diamond_ore/0_s.png').convert('RGBA'))
img_over1 = np.asarray(Image.open('NAPPs/result/diamond_ore/0.png').convert('RGBA'))

plt.imshow(img_over[:,:,3]==img_over1[:,:,3], cmap='gray')

# %%
inverted_layer = 255 - img_over[:,:,3]
layer = img_over[:,:,3]
inverted_layer = inverted_layer / 255
layer = layer / 255
ore_mask = np.multiply(img_over[:,:,1], layer)
plt.imshow( (ore_mask + np.multiply( img_base[:,:,1], 1-layer)), cmap='gray')

# %%
from BatchOverlaper import PRB_batch_overlaping, load_PBR_images

base_img = load_PBR_images('test_imgs/1')
#overlay_img = load_PBR_images('test_imgs/0')

plt.imshow(np.asarray(Image.open('test_imgs/1.png').convert('RGBA')))
